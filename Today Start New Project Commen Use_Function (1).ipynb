# %%
#                                        Dataset ko Import karne ke liye
df=pd.read_cvs("File_Pat.csv")
df=pd.read_json("File_Pat.json")

# %%
#          Total DataSet Me se Kitne be Row Lena 
df=pd.read_csv("File_Path",nrows=3)

#          Total DataSet Me se Kitne be Column Lena  (Column ko Columns ke Name se Nikalna)
df=pd.read_csv("File_Path",usecols=["Colname","Colname"])

#          Total DataSet Me se Kitne be Column Lena  (Column ko Index Number se Nikalna)
df=pd.read_csv("File_Path",usecols=[0,1,2])

#           DataSet Ke kisi bi Column ki Index Banana
df=pd.read_csv("File_Path",index_col=["Colname"])

#           DataSet Ke kisi bi Row Ko Header Banan
df=pd.read_csv("File_Path",header = Row_Number)

#           DataFrame Me Header Ka Name Dena
df=pd.read_csv("File_Path",name=["haedername","headername","headername"])

#           DataSet Ke Kisi bi Column Ke DataType ko Change Karna
df=pd.read_csv("File_Path",dtype={"Column":"Datatypename"})

# %%
#                      Kisi bi File ko CSV File me conver karne ke liye
df.to_csv("File_Path")
#                      Create Data me se Index ko Hatana
df.to_scv("File_Path",index=False)
#                      Create Data me se Header dena
df.to_scv("File_Path",header=[1,2,3])

# %%
#                                      Fast and last and Random row Dhekhane ke liye
df.sample()
df.head()
df.tail()

# %%
#                                          Row and Columns Dekhane ke liye
df.shape

# %%
# DataSet me Present Values
#                                         Row, Column, Datatype, File_Size, Null Value ect.
df.info()



-------------------------------------------------------------------
# DataSet ke Columns Ko Dhekna
df.columns
# DataSet ke Columns Ko Dhekna
df.feature_name

# %%
#                                 statistics Numerical columns par Only Apply  statistics Dhekhane ke liye
df.discrebe()

# %%
# DataSet me se Index Number Se Row  Nikalna
     Row     Row
    index   index
    stat    end
df[      :         ]

# DataSet me se Index Number Se Row and Columns Nikalna
        Row index          Columns
df.loc[[start:end],["ColName","Colname"]]

# DataSet me se Index Number Se Row and Columns Nikalna
        Row Index  Columns
df.loc[[start:end],  : ]

# DataSet me se Index Number Se Row and Columns Nikalna
         
df.iloc[Row index Number,Col index Number]

# DataSet me se Index Number Se Row and Columns Nikalna
         row         column
df.iloc[start:end , start:end ]

# %%
# Kisi Be Pure DataSet ko Numpy Array me Convert Karna
df.to_numpy()

# Kisi Be Pure DataSet ko Numpy Array me Convert Karna
import numpy as np
variable_name=np.asarray(DataSetName)
v

# %%
# Index ko Sort Karna Ascending and Decending Karna
df.sort_index(axis=0,ascending = False)

# %%
# DataSet Ki Kisi Bi Value Ko Change Karna
df["Colname"][IndexNumber]="NewColName"

# %%
# DataSet me se Kisi bi Columns Ko Drop karna
df.drop("Colname",axix=1)

# DataSet me se Kisi bi Row Ko Drop karna
df.drop(row index,axix=0)

# %%
# Missing/Nan Value Ko Drop Karna (Row wise)
df.dropna()
=================================================
================================================
# Missing/Nan Value Ko Drop Karna (Column wise)
df.dropna(subset=["ColName"])
=================================================
====================================================
------------------------------------------------
# Missing/Nan Value Ko Fill Karna 
df.fillna("Jis value se Fill karna ho ")

# Missing/Nan Value Ko Fill Karna (Column wise)
df.fillna({"Colname":"Jis value se fill karna ho","Colname":"Jis value se fill karna ho",})

# Missing/Nan Value Ko Fill Karna Upper and Niche ki Row se
df.fillna(method="ffill")
df.fillna(method="bfill")

----------------------------------------------------

# DataSet ki kis bi value ko kisi bi value se Replace Karna
df.replace(to_replace="old value",value"new value")

# DataSet ki kis bi value ko Fill Karna(Work Only for numerical Value)
df.interpolate()

# %%
# Do DataSet ko Marge Karke ek New DataSet Bana(Join)
pd.merge(DataSet1,DataSet2,on="CommenColums")

# Do DataSet ko Marge Karke ek New DataSet Bana(Join)
pd.merge(DataSet1,DataSet2, how = "right")
pd.merge(DataSet1,DataSet2, how = "left")
pd.merge(DataSet1,DataSet2, how = "outer")

# Join DataSet me Dhekana ki Kon sa DataSet Present or Kon sa Apsent hai
pd.merge(DataSet1,DataSet2, how = "outer",indicator = True)

---------------------------------------------------------------

# Merge function se Do Dataset Ko Join Karna (hstick Merg) Columns Wise
pd.concat([DataSet1,DataSet2],axis=1)

# Merge function se Do Dataset Ko Join Karna (vstick Merg) Row Wise
pd.concat([DataSet1,DataSet2],axis=0)
--------------------------------------------------------
# join Function Se Do DataSet ko Jodna
DataSet1.join(DataSet2)

# join Function Se Do DataSet ko Jodna(letf Join)
DataSet1.join(DataSet2, how = "left")

# join Function Se Do DataSet ko Jodna(right Join)
DataSet2.join(DataSet1, how = "right")

# join Function Se Do DataSet ko Jodna(inner Join)
DataSet2.join(DataSet1, how = "inner")
---------------------------------------------------
# Append Function Se Do DataSet ko Jodna(inner Join)
DataSet1.append(DataSet2)

# Index ko Ignore karna
DataSet1.append(DataSet2,ignore_index=True)

# %%
# GroupBy karna
NewvariableName = oldvariableName.groupby("Colname")
NewvariableName

for x,y in NewvariableName:
    print(x)
    print(y)
    
# Kisi ek Hi Columns ka Data Dekhana Groupby Se
NewvariableName.get_group("Colname")


# Kisi Bi dataset ka Sabi Columns Ka Min/Max nikalna Groupby se
NewvariableName.min()
NewvariableName.max()
NewvariableName.mean()

# %% [markdown]
# # datacode with Sharad

# %%
# DataSate ka Pura Data Print karane ke liye
print(df.to_string())

# %%
# Apne Target columns Ko Dekhana
df.target_name

# %%
# Nan Value ko Drop karna
df.dropna()
NewVariableName=df.dropna()
---------------------------------------------------------
# Nan Value ko Fill Karna Kisi Value se 
df.fillna(Fill Karne wali Value)
NewVariableName=df.fillna(Fill Karne wali Value)

# Kisi Spacic Columns me Nan Value Fill Karna
df["ColName"].fillna(Fill Karne wali Value)
----------------------------------------------------------------
# Nana Value ko Mean/Mode/Medin Value Se Fill Karnan
AnyvariableName=df.['ColName'].mean()/mode()/median()
df.['ColName'].fillna(AnyvarivaleName)
df
--------------------------------------------------------------
# Kisi bi Orignal DataSet ki New Copy Banana 
NewVariableName=df.copy()
copy

# %%
**************************************************************
**************************************************************

# Kisi Bi Columns ka DataType Change Karna
NewVariableName=pd.to_datetime(df.['ColName'])

****************************************************************
***************************************************************

# %% [markdown]
# # =================Above okkkkkkkkkk==================

# %%
# Kisi Bi Row Ki Value Ko Change Karna
df.loc[Row index Number,"ColName "] = Jo Value Fill Karna Ho

# %%
# Loop Se Kisi bi Value Ko Fill 
for i in df.index:
    if df.loc[i,"Colname"] > Target Value (Big / Shor Value )  (Conditions):
        df.loc[i,"Colname"] = Us Value ke Sthan par Kon si Value Fill Karna 
df
       
      
        
# Loop Se Kisi bi Value Ko Drop Karna  ==>  Not ye Chanege Main DataSet me Hoga
for i in df.index:
    if df.loc[i,"Colname"] > Target Value (Big / Shor Value )(Conditions):
        df.drop(i,inplace=True)
df

# %%
# DatSet Me Duplicat Value Chaque Karna
df.duplicated().sum()

# DataSet Me Kon Si Row Duplicat Hai
df.value_counts()

# DataSet me Se Duplicat Value Ko Drop Karna       ==> Not ye Function Main DataSet me change Hoga
df.drop_duplicates(inplace=True)

# %%
===============================================================
==============================================================
# DataSet Me Only for Null Value See
df.isnull().sum()
===============================================================
# Missing/Nan Value Ko Drop Karna (Row wise)
df.dropna()

# Missing/Nan Value Ko Drop Karna (Column wise)
df.dropna(subset=["ColName"])


=================================================================
=================================================================

# %% [markdown]
# #                            Campus x  pandas

# %%
# DataSet Ke kisi Columns Me Dhekhna ki Kon Si Value Kitni Bar Aay Hai / Value ki Frequvancy Chaque Karna
df['ColName'].value_counts()

# %%
# Kisi Bi DataSet Me Se koi bi Column Nikalna
NewName=df[["Colname","Colname","Colname"]]
NemName

# %%
===========================================================================
=======================================================================
# DataSet ke Kisi bi Columns me se Numerica Values Nikalna
df['ColName'].isdigit()
# DataSet ke Kisi bi Columns me se Categorical Values Nikalna
df['ColName'].iscategorical()

========================================================================
==========================================================================

# %%
cumpax pandas
part number 18
time 16:41

# %% [markdown]
# #                                 All MACHINE LEARNING ALGORITHM

# %% [markdown]
# # ...................(1)  Linear Regression...........

# %%
 from sklearn.linear_model import LinearRegression
lr = LinearRegression()
 
lr.fit(X_train, y_train)
 
lr.coef_
 
lr.intercept_
 
"""## Predict the value of Home and Test"""
# Single House ki Price 
X_test[0, :]
 
lr.predict([X_test[0, :]])

# All House Price give ML model 
lr.predict(X_test)
#  Test Data Give ML Model ko
y_test

# Accuracy Score Calculate Karna 
lr.score(X_test, y_test)

# %% [markdown]
# # .............Every Model Find Error.........

# %%
                                            ## Model Evaluation
# Any Model Find Value
y_pred = lr.predict(X_test)
y_pred
# Actucl Value 
y_test
 
from sklearn.metrics import mean_squared_error

#  ...............Mean Squre Error find  
mse = mean_squared_error(y_test, y_pred)
#  ...............Root Mean Squre Error find
rmse = np.sqrt(mse)
 
print('MSE = ', mse)
#  ...............Model Find Error find
print('RMSE = ', rmse)

# %% [markdown]
# # .................(2)   Ridge and Lasso Regression............

# %%
from sklearn.linear_model import Ridge, Lasso

# ======================= Ridge ==================

..............(1)...........

# Class Make
rd = Ridge()
# Model Fit karna
rd.fit(X_train,y_train)
# Model Score Find Karna
rd.score(X_test, y_test)

..............(2)...........

rd2 = Ridge(alpha = 2)
rd2.fit(X_train,y_train)
rd2.score(X_test, y_test)
# ---------------------------------------
# ---------------------------------------

# ========================= Lasso =========================

..............(1)...........

# Class Make
ls = Lasso()
# Model Fit Karna
ls.fit(X_train,y_train)
# Model Socre Find Karna
ls.score(X_test, y_test)

..............(2)...........

ls2 = Lasso(alpha=2)
ls2.fit(X_train,y_train)
ls2.score(X_test, y_test)

..............(3)...........

ls3 = Lasso(alpha=3)
ls3.fit(X_train,y_train)
ls3.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 rd = Ridge()
#       6 # Model Fit karna
# ----> 7 rd.fit(X_train,y_train)
#       8 # Model Score Find Karna
#       9 rd.score(X_test, y_test)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# # .................(3)  Polynomial Linear Regression...............................

# %%
# ====> Not Polynomial Model Ko Use Karte time LinearRegression Model ko Bi Import Karna Padata hai 

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures


# Class ya Object Crete Karna
poly_reg = PolynomialFeatures(degree=2)
# Model Fit Karna
poly_reg.fit(X_train)
# X_train and x_test Transform Karna 
X_train_poly = poly_reg.transform(X_train)
X_test_poly = poly_reg.transform(X_test)

# Sape Find Karna
X_train_poly.shape, X_test_poly.shape

# Class and Object Creat Karna
lr = LinearRegression()
# Fit Karana
lr.fit(X_train_poly, y_train)
# Score Find Karna
lr.score(X_test_poly, y_test,)
# One Price predict Karna
lr.predict([X_test_poly[0,:]])

# Model Calculate All Price Ko Pridict Karana 
y_pred = lr.predict(X_test_poly)
y_pred
# Actual Price 
y_test
# .............................Model Evaluation........................

# .............................Error Find Karna...................

from sklearn.metrics import mean_squared_error


#  ...............Mean Squre Error find  
mse = mean_squared_error(y_test, y_pred)
#  ...............Root Mean Squre Error find
rmse = np.sqrt(mse)
 
print('MSE = ', mse)
#  ...............Model Find Error find
print('RMSE = ', rmse)

# %% [markdown]
# # .................(4) Support Vector Regression.................

# %%
 
"""## Support Vector Regression - ML Model Training"""
 
from sklearn.svm import SVR

# ..............(1)...........

# Class Ya Object Make 
svr_rbf = SVR(kernel='rbf')
# Model Fit karna
svr_rbf.fit(X_train, y_train)
# Score Find Karna
svr_rbf.score(X_test, y_test)

# ..............(2)...........

# Class Ya Object Banan 
svr_linear = SVR(kernel='linear')
# Model Fit Karna
svr_linear.fit(X_train, y_train)
# Score Find Karna
svr_linear.score(X_test, y_test)

# ..............(3)...........

# Class Ya Object Banan 
svr_poly = SVR(kernel='poly',degree=2,)
# Model Fit Karna
svr_poly.fit(X_train, y_train)
# Score Find Karna
svr_poly.score(X_test, y_test)
 
# ..............(4)...........
    
# Class Ya Object Banan 
svr_sigmoid = SVR(kernel='sigmoid',degree=2,)
# Model Fit Karna
svr_sigmoid.fit(X_train, y_train)
# Score Find Karna
svr_sigmoid.score(X_test, y_test)

# ..............(5)...........

# Class Ya Object Banan 
svr_precomputed = SVR(kernel='precomputed',degree=3,)
# Model Fit Karna
svr_precomputed.fit(X_train, y_train)
# Score Find Karna
svr_precomputed.score(X_test, y_test)
    
#      One Row Price see
X_test[0]
# model Ko One Row Ki Price Give 
svr_linear.predict([X_test[0]])
# All Price Give 
y_pred = svr_linear.predict(X_test)
y_pred
# Acctual Price 
y_test
 
# ...........................Model Eveluate Karna.......................


from sklearn.metrics import mean_squared_error

#  ...............Mean Squre Error find  
mse = mean_squared_error(y_test, y_pred)
#  ...............Root Mean Squre Error find
rmse = np.sqrt(mse)
 
print('MSE = ', mse)
#  ...............Model Find Error find
print('RMSE = ', rmse)



======================================================================================
======================================================================================
---------------------- Support Vector Classification Model--------------------
======================================================================================
======================================================================================

from sklearn.svm import SVC

# ..............(1)...........

#  Calass Ya Object Make
classification_rbf = SVC(kernel='rbf')
# Model Fit Karna
classification_rbf.fit(X_train, y_train)
# Score Find Karran
classification_rbf.score(X_test, y_test)

# ..............(2)...........
 
"""## SVC with kernel Polynomial"""

# Calass Ya Object Make
classification_poly = SVC(kernel='poly', degree=2)
#  Model Fit Karna
classification_poly.fit(X_train_sc, y_train)
# Score Find Karran
classification_poly.score(X_test_sc, y_test)

# ..............(3)........... 
"""## SVC with Kernel Linear"""

# Calass Ya Object Make 
classification_linear = SVC(kernel='linear')
#  Model Fit Karna
classification_linear.fit(X_train_sc, y_train) 
# Score Find Karran
classification_linear.score(X_test_sc, y_test)

# %% [markdown]
# # .................(5)Decision Tree Regression................

# %%
 
from sklearn.tree import DecisionTreeRegressor

# Class Ya Object Make 
regressor = DecisionTreeRegressor(criterion='mse')
# Model Fit Karana
regressor.fit(X_train, y_train)
# Socre Find Karana
regressor.score(X_test, y_test)
 
"""## Predict the value of Home"""

# One House Price Find 
X_test.iloc[-1, :]
# One House Price Give Model Two Dimention
regressor.predict([X_test.iloc[-1, :]])
# Acctual Price House 
y_test.iloc[-1]
# All Price Give Model 
pred = regressor.predict(X_test)
pred
# Acctual Price 
y_test



# =======================================================================
# =======================================================================
# ................ Train Decision Tree Classification Model.............
# =======================================================================
# =======================================================================
    
from sklearn.tree import DecisionTreeClassifier

# ..............(1)........... 

# Class Ya Object Make 
classifier = DecisionTreeClassifier(criterion='gini')
# Model Fit Karna
classifier.fit(X_train, y_train)
# Score Find Karran 
classifier.score(X_test, y_test)
 
..............(2)...........     

# Class Ya Object Make 
classifier_entropy = DecisionTreeClassifier(criterion='entropy')
# Model Fit Karna
classifier_entropy.fit(X_train, y_train)
#  Score Find Karran  
classifier_entropy.score(X_test, y_test)

# %% [markdown]
# # .................(6) Randome Forest Regression..............................

# %%
# Model Import
 
from sklearn.ensemble import RandomForestRegressor

# ........................(1)........................

# Class Ya object Make            (Kitne Tree Make Number)
regressor = RandomForestRegressor(n_estimators=100, criterion='mse')
# Model Fit Karna
regressor.fit(X_train, y_train)
# Score Find Karna 
regressor.score(X_test, y_test)

........................(2)........................

# Class Ya object Make                (Kitne Tree Make Number)
regressor_500 = RandomForestRegressor(n_estimators=500, criterion='mse')
# Model Fit Karna
regressor_500.fit(X_train, y_train)
#  Score Find Karna 
regressor_500.score(X_test, y_test)
 
"""## Predict the value of Home"""
# DataSet me Se Last Ya Koi 1 Value Lena
X_test.iloc[-1, :]
# Value Ko 2 Dimention Me Convert Karna 
regressor.predict([X_test.iloc[-1, :]])
# Actual Price 
y_test.iloc[-1]
# All Valu Give Model Ko 
y_pred = regressor.predict(X_test)
y_pred
# House Ki Actual Price 
y_test



# =============================================================================
# ============================================================================
# """## Train Random Forest Classification Model"""
# =============================================================================
# ============================================================================

# Model Ko Import Karna
from sklearn.ensemble import RandomForestClassifier
 
# Class Ya Object Make           (Kitne Tree Make Number)            
classifier = RandomForestClassifier(n_estimators=100, criterion='gini')
# Model Fit Karna
classifier.fit(X_train, y_train)
# Score Find Karana 
classifier.score(X_test, y_test)
 
"""## Predict Cancer"""
# Patinat One Detais
patient1 = [17.99,
 10.38,
 122.8,
 1001.0,
 0.1184,
 0.2776,
 0.3001,
 0.1471,
 0.2419,
 0.07871,
 1.095,
 0.9053,
 8.589,
 153.4,
 0.006399,
 0.04904,
 0.05373,
 0.01587,
 0.03003,
 0.006193,
 25.38,
 17.33,
 184.6,
 2019.0,
 0.1622,
 0.6656,
 0.7119,
 0.2654,
 0.4601,
 0.1189]
 
# patinet Detais Ko Array Format Me convert Karna    
patient1 = np.array([patient1])
patient1
# Patinat One Ka Resut Predict 
classifier.predict(patient1)
 
#  Model Ki Predict Resut Variable Me assine Karna
pred = classifier.predict(patient1)

# Condition Dean
if pred[0] == 0:
  print('Patient has Cancer (malignant tumor)')
else:
  print('Patient has no Cancer (malignant benign)')

# %% [markdown]
# # .................(7)  K Nearest Neighbo (KNN)..................

# %%
#  Model Import
from sklearn.neighbors import KNeighborsClassifier
 
# Class Ya Object Make  (Number Modifi Bi kar sakte) 
classifier = KNeighborsClassifier(n_neighbors=5)
# Model Fit 
classifier.fit(X_train, y_train)
#  Score Find Karna
classifier.score(X_test, y_test)
 
"""## Predict Cancer"""
# 1 patient Ki Information  
patient1 = [17.99,
 10.38,
 122.8,
 1001.0,
 0.1184,
 0.2776,
 0.3001,
 0.1471,
 0.2419,
 0.07871,
 1.095,
 0.9053,
 8.589,
 153.4,
 0.006399,
 0.04904,
 0.05373,
 0.01587,
 0.03003,
 0.006193,
 25.38,
 17.33,
 184.6,
 2019.0,
 0.1622,
 0.6656,
 0.7119,
 0.2654,
 0.4601,
 0.1189]
# 2D Array Me Convert Karna 
patient1 = np.array([patient1]) 
patient1
# Model Ne Pridict Kiya Resut 
classifier.predict(patient1)
# Result Ko Varialble me Assine Kiya  
pred = classifier.predict(patient1)
 
# Condition Dena    
if pred[0] == 0:
  print('Patient has Cancer (malignant tumor)')
else:
  print('Patient has no Cancer (malignant benign)')
