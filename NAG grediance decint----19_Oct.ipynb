# %%
import numpy as np
import pandas as pd

# %%
! pip install TensorFlow
import tensorflow as tf
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
data=pd.read_csv("C:\\Users\\HP\\Desktop\\Churn_Modelling.csv")
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
x=data.iloc[:,3:-1].values
y=data.iloc[:,-1].values

# %%
le=LabelEncoder()
x[:,1]=le.fit_transform(x[:,1])
x[:,2]=le.fit_transform(x[:,2])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(x_train)
X_test=scaler.transform(x_test)

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Dense(64,activation='relu',input_dim=X_train.shape[1]),
    tf.keras.layers.Dense(64,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid')
])

# %%
loss_fn=tf.keras.losses.BinaryCrossentropy()
metrics=['accuracy']

# %%
learning_rate=0.001
momentum=0.9
optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate,momentum=momentum,nesterov=True)

# %%
model.compile(optimizer=optimizer,loss=loss_fn,metrics=metrics)

# %%
epochs=10
batch_size=32
model.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,validation_split=0.2)
# Out:
# Epoch 1/10
# 200/200 [==============================] - 2s 5ms/step - loss: 0.5409 - accuracy: 0.7595 - val_loss: 0.4759 - val_accuracy: 0.7987
# Epoch 2/10
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4755 - accuracy: 0.7936 - val_loss: 0.4530 - val_accuracy: 0.7987
# Epoch 3/10
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4579 - accuracy: 0.7961 - val_loss: 0.4387 - val_accuracy: 0.8037
# Epoch 4/10
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4459 - accuracy: 0.8014 - val_loss: 0.4295 - val_accuracy: 0.8144
# Epoch 5/10
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4376 - accuracy: 0.8091 - val_loss: 0.4226 - val_accuracy: 0.8206
# Epoch 6/10
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4317 - accuracy: 0.8123 - val_loss: 0.4183 - val_accuracy: 0.8269
# Epoch 7/10
# ...

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print('Test Loss:',test_loss)
print('Test Accuracy',test_acc)
# Out:
# 63/63 [==============================] - 0s 3ms/step - loss: 0.4033 - accuracy: 0.8315
# Test Loss: 0.40326961874961853
# Test Accuracy 0.8314999938011169

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\HP\\Desktop\\Main File\\Project Data\\supply_chain.csv')
df
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 0      haircare   SKU0  69.808006            55                      802
# 1      skincare   SKU1  14.843523            95                      736
# 2      haircare   SKU2  11.319683            34                        8
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# ..          ...    ...        ...           ...                      ...
# 95     haircare  SKU95  77.903927            65                      672
# 96    cosmetics  SKU96  24.423131            29                      324
# 97     haircare  SKU97   3.526111            56                       62
# 98     skincare  SKU98  19.754605            43                      913
# 99     haircare  SKU99  68.517833            17                      627
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# ...

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
